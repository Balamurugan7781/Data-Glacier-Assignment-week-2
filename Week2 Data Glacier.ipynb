# %%
# there are 4 datasets.....
# My name is Balamurugan Purushothaman....
# here we are going to check the following problem statement....
# Determine which files should be joined versus which ones should be appended
# Create master data and explain the relationship
# Identify and remove duplicates
# Perform other analysis like NA value and outlier detection
# now let's import those 4 datasets....

# %%
# importing necessary libraries....
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\balam\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# importing the first dataset....
Cab_data = pd.read_csv(r"C:\Users\balam\OneDrive\Documents\SOP Docs\Liverpool\Data Science Parts\Data Glacier Assignments\Week 2 Datasets\Cab_Data.csv")

# %%
City = pd.read_csv(r"C:\Users\balam\OneDrive\Documents\SOP Docs\Liverpool\Data Science Parts\Data Glacier Assignments\Week 2 Datasets\City.csv")

# %%
customer = pd.read_csv(r"C:\Users\balam\OneDrive\Documents\SOP Docs\Liverpool\Data Science Parts\Data Glacier Assignments\Week 2 Datasets\Customer_ID.csv")

# %%
transaction = pd.read_csv(r"C:\Users\balam\OneDrive\Documents\SOP Docs\Liverpool\Data Science Parts\Data Glacier Assignments\Week 2 Datasets\Transaction_ID.csv")

# %%
Cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
# now studying about Cab_data dataset....
print(Cab_data.shape)
# Out:
# (359392, 7)

# %%
# printing the information about the dataset....
print(Cab_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# None

# %%
# now check if there is any missing values in the dataset....
# defining a function to check if there is any missing value in the dataset...
def is_null(df):
    return df.isnull().sum()

# %%
is_null(Cab_data)
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
# there are no null values in Cab Data....
# now check regarding NA values.....
def is_na(df):
    return df.isna().sum()

# %%
is_na(Cab_data)
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
# there are no NA values....
# now let's try for other datasets....
print(City.shape)
# Out:
# (20, 3)

# %%
is_null(City)
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
is_na(City)
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
# now try for customer dataset....
print(customer.shape)
# Out:
# (49171, 4)

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
is_null(customer)
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
is_na(customer)
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
Cab_data['Cost of Trip'].describe()
# Out:
# count    359392.000000
# mean        286.190113
# std         157.993661
# min          19.000000
# 25%         151.200000
# 50%         282.480000
# 75%         413.683200
# max         691.200000
# Name: Cost of Trip, dtype: float64

# %%
Cab_data['Company'].unique()
# Out:
# array(['Pink Cab', 'Yellow Cab'], dtype=object)

# %%
# now take care of Transaction....
print(transaction.shape)
# Out:
# (440098, 3)

# %%
is_na(transaction)
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
# now we get to know that both Cab_data and City have same attributes

# %%
# I mean the City....
# merge those attributes...m
merged_df = pd.merge(Cab_data,City,on='City')

# %%
merged_df.head(2)
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
#
#    Price Charged  Cost of Trip Population     Users
# 0         370.95       313.635   814,885    24,701
# 1         358.52       334.854   814,885    24,701

# %%
merged_df.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
merged_df_2 = pd.merge(merged_df,transaction,on="Transaction ID",how="right")

# %%
merged_df_2.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011         42377.0  Pink Cab  ATLANTA GA         30.45
# 1        10000012         42375.0  Pink Cab  ATLANTA GA         28.62
# 2        10000013         42371.0  Pink Cab  ATLANTA GA          9.04
# 3        10000014         42376.0  Pink Cab  ATLANTA GA         33.17
# 4        10000015         42372.0  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip Population     Users  Customer ID Payment_Mode
# 0         370.95       313.635   814,885    24,701         29290         Card
# 1         358.52       334.854   814,885    24,701         27703         Card
# 2         125.20        97.632   814,885    24,701         28712         Cash
# 3         377.40       351.602   814,885    24,701         28020         Cash
# 4         114.62        97.776   814,885    24,701         27182         Card

# %%
final_df = pd.merge(merged_df_2,customer,on="Customer ID")

# %%
final_df
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011         42377.0    Pink Cab     ATLANTA GA
# 1             10000012         42375.0    Pink Cab     ATLANTA GA
# 2             10000013         42371.0    Pink Cab     ATLANTA GA
# 3             10000014         42376.0    Pink Cab     ATLANTA GA
# 4             10000015         42372.0    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 440093        10440104         43104.0  Yellow Cab  WASHINGTON DC
# 440094        10440105         43105.0  Yellow Cab  WASHINGTON DC
# 440095        10440106         43105.0  Yellow Cab  WASHINGTON DC
# 440096        10440107         43102.0  Yellow Cab  WASHINGTON DC
# 440097        10440108             NaN         NaN            NaN
#
#         KM Travelled  Price Charged  Cost of Trip Population      Users  \
# 0              30.45         370.95      313.6350   814,885     24,701
# ...

# %%
# dataset merging is carried based on foreign keys....
# now merging 

rows_with_null = final_df[final_df.isnull().any(axis=1)]
print("NOF rows with nulls:", len(rows_with_null))
print("City with no transactions:", rows_with_null["City"].values)


final_df = final_df.dropna()
rows_with_null = final_df[final_df.isnull().any(axis=1)]
print('NOF rows with nulls with "SAN FRANCISCO CA" row dropped:', len(rows_with_null))


'''print("NOF duplicate Transactions in cab_data:", cab_data[cab_data.duplicated("Transaction ID")]["Transaction ID"].count())
print("NOF duplicate Transactions in transaction_id:", transaction_id[transaction_id.duplicated("Transaction ID")]["Transaction ID"].count())
print("NOF duplicate Users:", customer_id[customer_id.duplicated("Customer ID")]["Customer ID"].count())'''
# Out:
# NOF rows with nulls: 80706
# City with no transactions: [nan nan nan ... nan nan nan]
# NOF rows with nulls with "SAN FRANCISCO CA" row dropped: 0
# 'print("NOF duplicate Transactions in cab_data:", cab_data[cab_data.duplicated("Transaction ID")]["Transaction ID"].count())\nprint("NOF duplicate Transactions in transaction_id:", transaction_id[transaction_id.duplicated("Transaction ID")]["Transaction ID"].count())\nprint("NOF duplicate Users:", customer_id[customer_id.duplicated("Customer ID")]["Customer ID"].count())'

# %%
# now grouping with Index values....
pink = final_df[final_df["Company"]=="Pink Cab"].sort_values("Date of Travel").reset_index(drop=True)

# %%
pink
# Out:
#        Transaction ID  Date of Travel   Company            City  KM Travelled  \
# 0            10000164         42371.0  Pink Cab      PHOENIX AZ          8.55
# 1            10000060         42371.0  Pink Cab      CHICAGO IL         35.34
# 2            10000070         42371.0  Pink Cab       DENVER CO          7.02
# 3            10000127         42371.0  Pink Cab  LOS ANGELES CA         38.00
# 4            10000370         42371.0  Pink Cab       TUCSON AZ          5.40
# ...               ...             ...       ...             ...           ...
# 84706        10436963         43465.0  Pink Cab  LOS ANGELES CA         38.00
# 84707        10433575         43465.0  Pink Cab     NEW YORK NY         42.00
# 84708        10433249         43465.0  Pink Cab       DENVER CO         19.98
# 84709        10433255         43465.0  Pink Cab  LOS ANGELES CA         38.94
# 84710        10436747         43465.0  Pink Cab      CHICAGO IL         35.03
#
# ...

# %%
yellow_cab = final_df[final_df["Company"]=="Yellow Cab"].sort_values("Date of Travel").reset_index(drop=True)

# %%
yellow_cab
# Out:
#         Transaction ID  Date of Travel     Company            City  \
# 0             10000384         42371.0  Yellow Cab      ATLANTA GA
# 1             10000706         42371.0  Yellow Cab  LOS ANGELES CA
# 2             10000705         42371.0  Yellow Cab  LOS ANGELES CA
# 3             10000525         42371.0  Yellow Cab      CHICAGO IL
# 4             10000526         42371.0  Yellow Cab      CHICAGO IL
# ...                ...             ...         ...             ...
# 274676        10437627         43465.0  Yellow Cab      ATLANTA GA
# 274677        10434811         43465.0  Yellow Cab  LOS ANGELES CA
# 274678        10435425         43465.0  Yellow Cab     NEW YORK NY
# 274679        10438444         43465.0  Yellow Cab  LOS ANGELES CA
# 274680        10436500         43465.0  Yellow Cab   WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip   Population      Users  \
# 0              33.93        1341.17      464.1624     814,885     24,701
# ...
